# %%
import os
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array, save_img
from tensorflow.keras.preprocessing import image

# %%
# Paths for the original images and augmented images
source_dir = "E:/JAIN/PCL/Plant_Anomaly_Detection/dataset/pomegranate/healthy"
target_dir = "E:/JAIN/PCL/Plant_Anomaly_Detection/data_augmented/pomegranate/healthy"

# %%
# Make directory for augmented images if it doesn’t exist
os.makedirs(target_dir, exist_ok=True)

# Create an ImageDataGenerator for augmentations
datagen = ImageDataGenerator(
    rotation_range=90,  # Random rotation (0-90 degrees)
    width_shift_range=0.2,  # Horizontal shift
    height_shift_range=0.2,  # Vertical shift
    shear_range=0.2,  # Shearing
    zoom_range=0.2,  # Zooming
    horizontal_flip=True,  # Horizontal flip
    vertical_flip=True,  # Vertical flip
    brightness_range=[0.5, 1.5],  # Brightness adjustment
    fill_mode='nearest'  # Handling pixels that are newly created by transformations
)

# Function to check if the file is an image
def is_image(file_name):
    valid_extensions = ['.jpg', '.jpeg', '.png', '.bmp', '.gif']
    return any(file_name.lower().endswith(ext) for ext in valid_extensions)

# Function to generate augmented images and save them with serial numbering
def generate_augmented_images(img_path, base_name, datagen, target_dir):
    img = load_img(img_path)
    x = img_to_array(img)
    x = x.reshape((1,) + x.shape)

    i = 1
    for batch in datagen.flow(x, batch_size=1):
        augmented_img = batch[0].astype(np.uint8)
        augmented_img_name = f"{base_name}_{i}.jpg"
        augmented_img_path = os.path.join(target_dir, augmented_img_name)
        save_img(augmented_img_path, augmented_img)
        print(f"Saved augmented image: {augmented_img_name}")
        i += 1
        if i > 10:
            break

# Process each image in the source directory
for img_name in os.listdir(source_dir):
    img_path = os.path.join(source_dir, img_name)

    # Skip non-image files
    if not is_image(img_name):
        print(f"Skipping non-image file: {img_name}")
        continue

    print(f"Processing image: {img_path}")

    try:
        # Load the image
        img = load_img(img_path)
        x = img_to_array(img)
        x = x.reshape((1,) + x.shape)

        # Extract the base name without the extension (e.g., "0013_0001")
        base_name = img_name.split('.')[0]  # Example: "0013_0001"

        # Generate and save augmented images
        generate_augmented_images(img_path, base_name, datagen, target_dir)

    except Exception as e:
        print(f"Error: Augmented image not saved for {img_name}. Exception: {e}")
# Out:
# Processing image: E:/JAIN/PCL/Plant_Anomaly_Detection/dataset/pomegranate/healthy\0009_0251.JPG
# Saved augmented image: 0009_0251_1.jpg
# Saved augmented image: 0009_0251_2.jpg
# Saved augmented image: 0009_0251_3.jpg
# Saved augmented image: 0009_0251_4.jpg
# Saved augmented image: 0009_0251_5.jpg
# Saved augmented image: 0009_0251_6.jpg
# Saved augmented image: 0009_0251_7.jpg
# Saved augmented image: 0009_0251_8.jpg
# Saved augmented image: 0009_0251_9.jpg
# Saved augmented image: 0009_0251_10.jpg
# Processing image: E:/JAIN/PCL/Plant_Anomaly_Detection/dataset/pomegranate/healthy\0009_0252.JPG
# Saved augmented image: 0009_0252_1.jpg
# Saved augmented image: 0009_0252_2.jpg
# Saved augmented image: 0009_0252_3.jpg
# Saved augmented image: 0009_0252_4.jpg
# Saved augmented image: 0009_0252_5.jpg
# Saved augmented image: 0009_0252_6.jpg
# Saved augmented image: 0009_0252_7.jpg
# Saved augmented image: 0009_0252_8.jpg
# Saved augmented image: 0009_0252_9.jpg
# Saved augmented image: 0009_0252_10.jpg
# Processing image: E:/JAIN/PCL/Plant_Anomaly_Detection/dataset/pomegranate/healthy\0009_0253.JPG
# Saved augmented image: 0009_0253_1.jpg
# Saved augmented image: 0009_0253_2.jpg
# Saved augmented image: 0009_0253_3.jpg
# Saved augmented image: 0009_0253_4.jpg
# Saved augmented image: 0009_0253_5.jpg
# Saved augmented image: 0009_0253_6.jpg
# Saved augmented image: 0009_0253_7.jpg
# Saved augmented image: 0009_0253_8.jpg
# Saved augmented image: 0009_0253_9.jpg
# Saved augmented image: 0009_0253_10.jpg
# Processing image: E:/JAIN/PCL/Plant_Anomaly_Detection/dataset/pomegranate/healthy\0009_0254.JPG
# Saved augmented image: 0009_0254_1.jpg
# Saved augmented image: 0009_0254_2.jpg
# Saved augmented image: 0009_0254_3.jpg
# Saved augmented image: 0009_0254_4.jpg
# Saved augmented image: 0009_0254_5.jpg
# Saved augmented image: 0009_0254_6.jpg
# Saved augmented image: 0009_0254_7.jpg
# Saved augmented image: 0009_0254_8.jpg
# Saved augmented image: 0009_0254_9.jpg
# Saved augmented image: 0009_0254_10.jpg
# Processing image: E:/JAIN/PCL/Plant_Anomaly_Detection/dataset/pomegranate/healthy\0009_0255.JPG
# Saved augmented image: 0009_0255_1.jpg
# Saved augmented image: 0009_0255_2.jpg
# Saved augmented image: 0009_0255_3.jpg
# Saved augmented image: 0009_0255_4.jpg
# Saved augmented image: 0009_0255_5.jpg
# Saved augmented image: 0009_0255_6.jpg
# Saved augmented image: 0009_0255_7.jpg
# Saved augmented image: 0009_0255_8.jpg
# Saved augmented image: 0009_0255_9.jpg
# Saved augmented image: 0009_0255_10.jpg
# Processing image: E:/JAIN/PCL/Plant_Anomaly_Detection/dataset/pomegranate/healthy\0009_0256.JPG
# Saved augmented image: 0009_0256_1.jpg
# Saved augmented image: 0009_0256_2.jpg
# Saved augmented image: 0009_0256_3.jpg
# Saved augmented image: 0009_0256_4.jpg
# Saved augmented image: 0009_0256_5.jpg
# Saved augmented image: 0009_0256_6.jpg
# Saved augmented image: 0009_0256_7.jpg
# Saved augmented image: 0009_0256_8.jpg
# Saved augmented image: 0009_0256_9.jpg
# Saved augmented image: 0009_0256_10.jpg
# Processing image: E:/JAIN/PCL/Plant_Anomaly_Detection/dataset/pomegranate/healthy\0009_0257.JPG
# Saved augmented image: 0009_0257_1.jpg
# Saved augmented image: 0009_0257_2.jpg
# Saved augmented image: 0009_0257_3.jpg
# Saved augmented image: 0009_0257_4.jpg
# Saved augmented image: 0009_0257_5.jpg
# Saved augmented image: 0009_0257_6.jpg
# Saved augmented image: 0009_0257_7.jpg
# Saved augmented image: 0009_0257_8.jpg
# Saved augmented image: 0009_0257_9.jpg
# Saved augmented image: 0009_0257_10.jpg
# Processing image: E:/JAIN/PCL/Plant_Anomaly_Detection/dataset/pomegranate/healthy\0009_0258.JPG
# Saved augmented image: 0009_0258_1.jpg
# Saved augmented image: 0009_0258_2.jpg
# Saved augmented image: 0009_0258_3.jpg
# Saved augmented image: 0009_0258_4.jpg
# Saved augmented image: 0009_0258_5.jpg
# Saved augmented image: 0009_0258_6.jpg
# Saved augmented image: 0009_0258_7.jpg
# Saved augmented image: 0009_0258_8.jpg
# Saved augmented image: 0009_0258_9.jpg
# Saved augmented image: 0009_0258_10.jpg
# Processing image: E:/JAIN/PCL/Plant_Anomaly_Detection/dataset/pomegranate/healthy\0009_0259.JPG
# Saved augmented image: 0009_0259_1.jpg
# Saved augmented image: 0009_0259_2.jpg
# Saved augmented image: 0009_0259_3.jpg
# Saved augmented image: 0009_0259_4.jpg
# Saved augmented image: 0009_0259_5.jpg
# Saved augmented image: 0009_0259_6.jpg
# Saved augmented image: 0009_0259_7.jpg
# Saved augmented image: 0009_0259_8.jpg
# Saved augmented image: 0009_0259_9.jpg
# Saved augmented image: 0009_0259_10.jpg
# Processing image: E:/JAIN/PCL/Plant_Anomaly_Detection/dataset/pomegranate/healthy\0009_0260.JPG
# Saved augmented image: 0009_0260_1.jpg
# Saved augmented image: 0009_0260_2.jpg
# Saved augmented image: 0009_0260_3.jpg
# Saved augmented image: 0009_0260_4.jpg
# Saved augmented image: 0009_0260_5.jpg
# Saved augmented image: 0009_0260_6.jpg
# Saved augmented image: 0009_0260_7.jpg
# Saved augmented image: 0009_0260_8.jpg
# Saved augmented image: 0009_0260_9.jpg
# Saved augmented image: 0009_0260_10.jpg
# Processing image: E:/JAIN/PCL/Plant_Anomaly_Detection/dataset/pomegranate/healthy\0009_0261.JPG
# Saved augmented image: 0009_0261_1.jpg
# Saved augmented image: 0009_0261_2.jpg
# Saved augmented image: 0009_0261_3.jpg
# Saved augmented image: 0009_0261_4.jpg
# Saved augmented image: 0009_0261_5.jpg
# Saved augmented image: 0009_0261_6.jpg
# Saved augmented image: 0009_0261_7.jpg
# Saved augmented image: 0009_0261_8.jpg
# Saved augmented image: 0009_0261_9.jpg
# Saved augmented image: 0009_0261_10.jpg
# Processing image: E:/JAIN/PCL/Plant_Anomaly_Detection/dataset/pomegranate/healthy\0009_0262.JPG
# Saved augmented image: 0009_0262_1.jpg
# Saved augmented image: 0009_0262_2.jpg
# Saved augmented image: 0009_0262_3.jpg
# Saved augmented image: 0009_0262_4.jpg
# Saved augmented image: 0009_0262_5.jpg
# Saved augmented image: 0009_0262_6.jpg
# Saved augmented image: 0009_0262_7.jpg
# Saved augmented image: 0009_0262_8.jpg
# Saved augmented image: 0009_0262_9.jpg
# Saved augmented image: 0009_0262_10.jpg
# Processing image: E:/JAIN/PCL/Plant_Anomaly_Detection/dataset/pomegranate/healthy\0009_0263.JPG
# Saved augmented image: 0009_0263_1.jpg
# Saved augmented image: 0009_0263_2.jpg
# Saved augmented image: 0009_0263_3.jpg
# Saved augmented image: 0009_0263_4.jpg
# Saved augmented image: 0009_0263_5.jpg
# Saved augmented image: 0009_0263_6.jpg
# Saved augmented image: 0009_0263_7.jpg
# Saved augmented image: 0009_0263_8.jpg
# Saved augmented image: 0009_0263_9.jpg
# Saved augmented image: 0009_0263_10.jpg
# Processing image: E:/JAIN/PCL/Plant_Anomaly_Detection/dataset/pomegranate/healthy\0009_0264.JPG
# Saved augmented image: 0009_0264_1.jpg
# Saved augmented image: 0009_0264_2.jpg
# Saved augmented image: 0009_0264_3.jpg
# Saved augmented image: 0009_0264_4.jpg
# Saved augmented image: 0009_0264_5.jpg
# Saved augmented image: 0009_0264_6.jpg
# Saved augmented image: 0009_0264_7.jpg
# Saved augmented image: 0009_0264_8.jpg
# Saved augmented image: 0009_0264_9.jpg
# Saved augmented image: 0009_0264_10.jpg
# Processing image: E:/JAIN/PCL/Plant_Anomaly_Detection/dataset/pomegranate/healthy\0009_0265.JPG
# Saved augmented image: 0009_0265_1.jpg
# Saved augmented image: 0009_0265_2.jpg
# Saved augmented image: 0009_0265_3.jpg
# Saved augmented image: 0009_0265_4.jpg
# Saved augmented image: 0009_0265_5.jpg
# Saved augmented image: 0009_0265_6.jpg
# Saved augmented image: 0009_0265_7.jpg
# Saved augmented image: 0009_0265_8.jpg
# Saved augmented image: 0009_0265_9.jpg
# Saved augmented image: 0009_0265_10.jpg
# Processing image: E:/JAIN/PCL/Plant_Anomaly_Detection/dataset/pomegranate/healthy\0009_0266.JPG
# Saved augmented image: 0009_0266_1.jpg
# Saved augmented image: 0009_0266_2.jpg
# Saved augmented image: 0009_0266_3.jpg
# Saved augmented image: 0009_0266_4.jpg
# Saved augmented image: 0009_0266_5.jpg
# Saved augmented image: 0009_0266_6.jpg
# Saved augmented image: 0009_0266_7.jpg
# Saved augmented image: 0009_0266_8.jpg
# Saved augmented image: 0009_0266_9.jpg
# Saved augmented image: 0009_0266_10.jpg
# Processing image: E:/JAIN/PCL/Plant_Anomaly_Detection/dataset/pomegranate/healthy\0009_0267.JPG
# Saved augmented image: 0009_0267_1.jpg
# Saved augmented image: 0009_0267_2.jpg
# Saved augmented image: 0009_0267_3.jpg
# Saved augmented image: 0009_0267_4.jpg
# Saved augmented image: 0009_0267_5.jpg
# Saved augmented image: 0009_0267_6.jpg
# Saved augmented image: 0009_0267_7.jpg
# Saved augmented image: 0009_0267_8.jpg
# Saved augmented image: 0009_0267_9.jpg
# Saved augmented image: 0009_0267_10.jpg
# Processing image: E:/JAIN/PCL/Plant_Anomaly_Detection/dataset/pomegranate/healthy\0009_0268.JPG
# Saved augmented image: 0009_0268_1.jpg
# Saved augmented image: 0009_0268_2.jpg
# Saved augmented image: 0009_0268_3.jpg
# Saved augmented image: 0009_0268_4.jpg
# Saved augmented image: 0009_0268_5.jpg
# Saved augmented image: 0009_0268_6.jpg
# Saved augmented image: 0009_0268_7.jpg
# Saved augmented image: 0009_0268_8.jpg
# Saved augmented image: 0009_0268_9.jpg
# Saved augmented image: 0009_0268_10.jpg
# Processing image: E:/JAIN/PCL/Plant_Anomaly_Detection/dataset/pomegranate/healthy\0009_0269.JPG
# Saved augmented image: 0009_0269_1.jpg
# Saved augmented image: 0009_0269_2.jpg
# Saved augmented image: 0009_0269_3.jpg
# Saved augmented image: 0009_0269_4.jpg
# Saved augmented image: 0009_0269_5.jpg
# Saved augmented image: 0009_0269_6.jpg
# Saved augmented image: 0009_0269_7.jpg
# Saved augmented image: 0009_0269_8.jpg
# Saved augmented image: 0009_0269_9.jpg
# Saved augmented image: 0009_0269_10.jpg
# Processing image: E:/JAIN/PCL/Plant_Anomaly_Detection/dataset/pomegranate/healthy\0009_0270.JPG
# Saved augmented image: 0009_0270_1.jpg
# Saved augmented image: 0009_0270_2.jpg
# Saved augmented image: 0009_0270_3.jpg
# Saved augmented image: 0009_0270_4.jpg
# Saved augmented image: 0009_0270_5.jpg
# Saved augmented image: 0009_0270_6.jpg
# Saved augmented image: 0009_0270_7.jpg
# Saved augmented image: 0009_0270_8.jpg
# Saved augmented image: 0009_0270_9.jpg
# Saved augmented image: 0009_0270_10.jpg
# Processing image: E:/JAIN/PCL/Plant_Anomaly_Detection/dataset/pomegranate/healthy\0009_0271.JPG
# Saved augmented image: 0009_0271_1.jpg
# Saved augmented image: 0009_0271_2.jpg
# Saved augmented image: 0009_0271_3.jpg
# Saved augmented image: 0009_0271_4.jpg
# Saved augmented image: 0009_0271_5.jpg
# Saved augmented image: 0009_0271_6.jpg
# Saved augmented image: 0009_0271_7.jpg
# Saved augmented image: 0009_0271_8.jpg
# Saved augmented image: 0009_0271_9.jpg
# Saved augmented image: 0009_0271_10.jpg
# Processing image: E:/JAIN/PCL/Plant_Anomaly_Detection/dataset/pomegranate/healthy\0009_0272.JPG
# Saved augmented image: 0009_0272_1.jpg
# Saved augmented image: 0009_0272_2.jpg
# Saved augmented image: 0009_0272_3.jpg
# Saved augmented image: 0009_0272_4.jpg
# Saved augmented image: 0009_0272_5.jpg
# Saved augmented image: 0009_0272_6.jpg
# Saved augmented image: 0009_0272_7.jpg
# Saved augmented image: 0009_0272_8.jpg
# Saved augmented image: 0009_0272_9.jpg
# Saved augmented image: 0009_0272_10.jpg
# Processing image: E:/JAIN/PCL/Plant_Anomaly_Detection/dataset/pomegranate/healthy\0009_0273.JPG
# Saved augmented image: 0009_0273_1.jpg
# Saved augmented image: 0009_0273_2.jpg
# Saved augmented image: 0009_0273_3.jpg
# Saved augmented image: 0009_0273_4.jpg
# Saved augmented image: 0009_0273_5.jpg
# Saved augmented image: 0009_0273_6.jpg
# Saved augmented image: 0009_0273_7.jpg
# Saved augmented image: 0009_0273_8.jpg
# Saved augmented image: 0009_0273_9.jpg
# Saved augmented image: 0009_0273_10.jpg
# Processing image: E:/JAIN/PCL/Plant_Anomaly_Detection/dataset/pomegranate/healthy\0009_0274.JPG
# Saved augmented image: 0009_0274_1.jpg
# Saved augmented image: 0009_0274_2.jpg
# Saved augmented image: 0009_0274_3.jpg
# Saved augmented image: 0009_0274_4.jpg
# Saved augmented image: 0009_0274_5.jpg
# Saved augmented image: 0009_0274_6.jpg
# Saved augmented image: 0009_0274_7.jpg
# Saved augmented image: 0009_0274_8.jpg
# Saved augmented image: 0009_0274_9.jpg
# Saved augmented image: 0009_0274_10.jpg
# Processing image: E:/JAIN/PCL/Plant_Anomaly_Detection/dataset/pomegranate/healthy\0009_0275.JPG
# Saved augmented image: 0009_0275_1.jpg
# Saved augmented image: 0009_0275_2.jpg
# Saved augmented image: 0009_0275_3.jpg
# Saved augmented image: 0009_0275_4.jpg
# Saved augmented image: 0009_0275_5.jpg
# Saved augmented image: 0009_0275_6.jpg
# Saved augmented image: 0009_0275_7.jpg
# Saved augmented image: 0009_0275_8.jpg
# Saved augmented image: 0009_0275_9.jpg
# Saved augmented image: 0009_0275_10.jpg
# Processing image: E:/JAIN/PCL/Plant_Anomaly_Detection/dataset/pomegranate/healthy\0009_0276.JPG
# Saved augmented image: 0009_0276_1.jpg
# Saved augmented image: 0009_0276_2.jpg
# Saved augmented image: 0009_0276_3.jpg
# Saved augmented image: 0009_0276_4.jpg
# Saved augmented image: 0009_0276_5.jpg
# Saved augmented image: 0009_0276_6.jpg
# Saved augmented image: 0009_0276_7.jpg
# Saved augmented image: 0009_0276_8.jpg
# Saved augmented image: 0009_0276_9.jpg
# Saved augmented image: 0009_0276_10.jpg
# Processing image: E:/JAIN/PCL/Plant_Anomaly_Detection/dataset/pomegranate/healthy\0009_0277.JPG
# Saved augmented image: 0009_0277_1.jpg
# Saved augmented image: 0009_0277_2.jpg
# Saved augmented image: 0009_0277_3.jpg
# Saved augmented image: 0009_0277_4.jpg
# Saved augmented image: 0009_0277_5.jpg
# Saved augmented image: 0009_0277_6.jpg
# Saved augmented image: 0009_0277_7.jpg
# Saved augmented image: 0009_0277_8.jpg
# Saved augmented image: 0009_0277_9.jpg
# Saved augmented image: 0009_0277_10.jpg
# Processing image: E:/JAIN/PCL/Plant_Anomaly_Detection/dataset/pomegranate/healthy\0009_0278.JPG
# Saved augmented image: 0009_0278_1.jpg
# Saved augmented image: 0009_0278_2.jpg
# Saved augmented image: 0009_0278_3.jpg
# Saved augmented image: 0009_0278_4.jpg
# Saved augmented image: 0009_0278_5.jpg
# Saved augmented image: 0009_0278_6.jpg
# Saved augmented image: 0009_0278_7.jpg
# Saved augmented image: 0009_0278_8.jpg
# Saved augmented image: 0009_0278_9.jpg
# Saved augmented image: 0009_0278_10.jpg
# Processing image: E:/JAIN/PCL/Plant_Anomaly_Detection/dataset/pomegranate/healthy\0009_0279.JPG
# Saved augmented image: 0009_0279_1.jpg
# Saved augmented image: 0009_0279_2.jpg
# Saved augmented image: 0009_0279_3.jpg
# Saved augmented image: 0009_0279_4.jpg
# Saved augmented image: 0009_0279_5.jpg
# Saved augmented image: 0009_0279_6.jpg
# Saved augmented image: 0009_0279_7.jpg
# Saved augmented image: 0009_0279_8.jpg
# Saved augmented image: 0009_0279_9.jpg
# Saved augmented image: 0009_0279_10.jpg
# Processing image: E:/JAIN/PCL/Plant_Anomaly_Detection/dataset/pomegranate/healthy\0009_0280.JPG
# Saved augmented image: 0009_0280_1.jpg
# Saved augmented image: 0009_0280_2.jpg
# Saved augmented image: 0009_0280_3.jpg
# Saved augmented image: 0009_0280_4.jpg
# Saved augmented image: 0009_0280_5.jpg
# Saved augmented image: 0009_0280_6.jpg
# Saved augmented image: 0009_0280_7.jpg
# Saved augmented image: 0009_0280_8.jpg
# Saved augmented image: 0009_0280_9.jpg
# Saved augmented image: 0009_0280_10.jpg
# Processing image: E:/JAIN/PCL/Plant_Anomaly_Detection/dataset/pomegranate/healthy\0009_0281.JPG
# Saved augmented image: 0009_0281_1.jpg
# Saved augmented image: 0009_0281_2.jpg
# Saved augmented image: 0009_0281_3.jpg
# Saved augmented image: 0009_0281_4.jpg
# Saved augmented image: 0009_0281_5.jpg
# Saved augmented image: 0009_0281_6.jpg
# Saved augmented image: 0009_0281_7.jpg
# Saved augmented image: 0009_0281_8.jpg
# Saved augmented image: 0009_0281_9.jpg
# Saved augmented image: 0009_0281_10.jpg
# Processing image: E:/JAIN/PCL/Plant_Anomaly_Detection/dataset/pomegranate/healthy\0009_0282.JPG
# Saved augmented image: 0009_0282_1.jpg
# Saved augmented image: 0009_0282_2.jpg
# Saved augmented image: 0009_0282_3.jpg
# Saved augmented image: 0009_0282_4.jpg
# Saved augmented image: 0009_0282_5.jpg
# Saved augmented image: 0009_0282_6.jpg
# Saved augmented image: 0009_0282_7.jpg
# Saved augmented image: 0009_0282_8.jpg
# Saved augmented image: 0009_0282_9.jpg
# Saved augmented image: 0009_0282_10.jpg
# Processing image: E:/JAIN/PCL/Plant_Anomaly_Detection/dataset/pomegranate/healthy\0009_0283.JPG
# Saved augmented image: 0009_0283_1.jpg
# Saved augmented image: 0009_0283_2.jpg
# Saved augmented image: 0009_0283_3.jpg
# Saved augmented image: 0009_0283_4.jpg
# Saved augmented image: 0009_0283_5.jpg
# Saved augmented image: 0009_0283_6.jpg
# Saved augmented image: 0009_0283_7.jpg
# Saved augmented image: 0009_0283_8.jpg
# Saved augmented image: 0009_0283_9.jpg
# Saved augmented image: 0009_0283_10.jpg
# Processing image: E:/JAIN/PCL/Plant_Anomaly_Detection/dataset/pomegranate/healthy\0009_0284.JPG
# Saved augmented image: 0009_0284_1.jpg
# Saved augmented image: 0009_0284_2.jpg
# Saved augmented image: 0009_0284_3.jpg
# Saved augmented image: 0009_0284_4.jpg
# Saved augmented image: 0009_0284_5.jpg
# Saved augmented image: 0009_0284_6.jpg
# Saved augmented image: 0009_0284_7.jpg
# Saved augmented image: 0009_0284_8.jpg
# Saved augmented image: 0009_0284_9.jpg
# Saved augmented image: 0009_0284_10.jpg
# Processing image: E:/JAIN/PCL/Plant_Anomaly_Detection/dataset/pomegranate/healthy\0009_0285.JPG
# Saved augmented image: 0009_0285_1.jpg
# Saved augmented image: 0009_0285_2.jpg
# Saved augmented image: 0009_0285_3.jpg
# Saved augmented image: 0009_0285_4.jpg
# Saved augmented image: 0009_0285_5.jpg
# Saved augmented image: 0009_0285_6.jpg
# Saved augmented image: 0009_0285_7.jpg
# Saved augmented image: 0009_0285_8.jpg
# Saved augmented image: 0009_0285_9.jpg
# Saved augmented image: 0009_0285_10.jpg
# Processing image: E:/JAIN/PCL/Plant_Anomaly_Detection/dataset/pomegranate/healthy\0009_0286.JPG
# Saved augmented image: 0009_0286_1.jpg
# Saved augmented image: 0009_0286_2.jpg
# Saved augmented image: 0009_0286_3.jpg
# Saved augmented image: 0009_0286_4.jpg
# Saved augmented image: 0009_0286_5.jpg
# Saved augmented image: 0009_0286_6.jpg
# Saved augmented image: 0009_0286_7.jpg
# Saved augmented image: 0009_0286_8.jpg
# Saved augmented image: 0009_0286_9.jpg
# Saved augmented image: 0009_0286_10.jpg
# Processing image: E:/JAIN/PCL/Plant_Anomaly_Detection/dataset/pomegranate/healthy\0009_0287.JPG
# Saved augmented image: 0009_0287_1.jpg
# Saved augmented image: 0009_0287_2.jpg
# Saved augmented image: 0009_0287_3.jpg
# Saved augmented image: 0009_0287_4.jpg
# Saved augmented image: 0009_0287_5.jpg
# Saved augmented image: 0009_0287_6.jpg
# Saved augmented image: 0009_0287_7.jpg
# Saved augmented image: 0009_0287_8.jpg
# Saved augmented image: 0009_0287_9.jpg
# Saved augmented image: 0009_0287_10.jpg
